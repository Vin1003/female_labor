# %%
import pandas as pd
dfa = pd.read_csv('Labor_force_participation_rate_ female.csv',encoding="GBK")
dfa
# Out:
#                                                country       2009       2010  \
# 0                                                Aruba        NaN        NaN
# 1                                          Afghanistan  42.709000  42.735001
# 2                                               Angola  75.255997  75.306999
# 3                                              Albania  44.945000  45.693001
# 4                                              Andorra        NaN        NaN
# 5                                           Arab World  20.052651  20.169026
# 6                                 United Arab Emirates  42.514999  44.028999
# 7                                            Argentina  48.823002  47.833000
# 8                                              Armenia  48.299000  49.587002
# 9                                       American Samoa        NaN        NaN
# 10                                 Antigua and Barbuda        NaN        NaN
# ...

# %%
dfa1 =dfa.dropna(axis=0,how='any') 
dfa1
# Out:
#                                                country       2009       2010  \
# 1                                          Afghanistan  42.709000  42.735001
# 2                                               Angola  75.255997  75.306999
# 3                                              Albania  44.945000  45.693001
# 5                                           Arab World  20.052651  20.169026
# 6                                 United Arab Emirates  42.514999  44.028999
# 7                                            Argentina  48.823002  47.833000
# 8                                              Armenia  48.299000  49.587002
# 11                                           Australia  58.821999  58.706001
# 12                                             Austria  53.373001  53.507000
# 13                                          Azerbaijan  59.617001  60.223000
# 14                                             Burundi  80.610001  80.349998
# ...

# %%
dfa2=print(list(dfa1.country))
dfa2
# Out:
# ['Afghanistan', 'Angola', 'Albania', 'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan', 'Botswana', 'Central African Republic', 'Canada', 'Central Europe and the Baltics', 'Switzerland', 'Channel Islands', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica', 'Caribbean small states', 'Cuba', 'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific', 'Europe & Central Asia (excluding high income)', 'Europe & Central Asia', 'Ecuador', 'Egypt, Arab Rep.', 'Euro area', 'Eritrea', 'Spain', 'Estonia', 'Ethiopia', 'European
# ...

# %%
x轴 = [int(x)for x in dfa.columns.values[-11:]]
x轴
# Out:
# [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
中国=list(dfa.loc['China'].values)[-11:]
中国
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [China] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-2e17de76a25a> in <module>()
# ----> 1 中国=list(dfa.loc['China'].values)[-11:]
#       2 中国
#
# ...

# %%
加拿大=list(dfa.loc['Canada'].values)[-11:]
加拿大

# %%
法国=list(df.loc['France'].values)[-11:]
法国
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6c1b03b390da> in <module>()
# ----> 1 法国=list(df.loc['France'].values)[-11:]
#       2 法国
#
# NameError: name 'df' is not defined

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar


def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(x轴)
        .add_yaxis("中", 中国)
        .add_yaxis("加", 加拿大)
        .add_yaxis("法", 法国)
        .set_global_opts(title_opts=opts.TitleOpts(title="男性劳动力参与率", subtitle="3个国家"))
    )
    return c
bar_base().render_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-726ac51b6413> in <module>()
#      14     )
#      15     return c
# ---> 16 bar_base().render_notebook()
#
# <ipython-input-8-726ac51b6413> in bar_base()
#       8         Bar()
#       9         .add_xaxis(x轴)
# ---> 10         .add_yaxis("中", 中国)
#      11         .add_yaxis("加", 加拿大)
#      12         .add_yaxis("法", 法国)
#
# NameError: name '中国' is not defined

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar


def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(x轴)
        .add_yaxis(
            "country",
            dfa2,
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="min")]),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="男性劳动力参与率"))
    )
    return c
bar_base().render_notebook()

# %%
df1 = pd.read_csv("School_enrollment.csv",encoding = 'gbk')
df1
# Out:
#                                                country     2009     2010  \
# 0                                                Aruba  1.43284  1.41237
# 1                                          Afghanistan  0.23639      NaN
# 2                                               Angola      NaN      NaN
# 3                                              Albania  1.36375  1.35543
# 4                                              Andorra      NaN      NaN
# 5                                           Arab World  1.04094  1.04136
# 6                                 United Arab Emirates      NaN      NaN
# 7                                            Argentina  1.49186  1.49160
# 8                                              Armenia  1.23839  1.21927
# 9                                       American Samoa      NaN      NaN
# 10                                 Antigua and Barbuda  2.27844  2.68089
# 11                                           Australia      NaN      NaN
# ...
